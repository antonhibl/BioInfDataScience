# %%
from vega import VegaLite
from vega_datasets import data

true=True
false=False
null=None

VegaLite({
  "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
  "title": "Distribution of Body Mass of Penguins",
  "params": [
    {
      "name": "raindrops",
      "value": -2,
      "bind": {"input": "range", "min": -4, "max": 0, "step": 0.01}
    },
    {"name": "include_zero", "value": true, "bind": {"input": "checkbox"}}
  ],
  "facet": {
    "row": {
      "field": "Species",
      "type": "nominal",
      "header": {"labelAngle": 0, "labelAlign": "left"}
    }
  },
  "spec": {
    "width": 800,
    "height": 75,
    "layer": [
      {
        "mark": "area",
        "params": [
          {
            "name": "grid",
            "select": {"type": "interval", "encodings": ["x"]},
            "bind": "scales"
          }
        ],
        "transform": [{"density": "Body Mass (g)", "groupby": ["Species"]}],
        "encoding": {
          "x": {
            "field": "value",
            "type": "quantitative",
            "title": "Body Mass (g)",
            "scale": {"zero": {"expr": "include_zero"}}
          },
          "y": {
            "field": "density",
            "type": "quantitative",
            "axis": {
              "title": "",
              "grid": false,
              "labels": false,
              "ticks": false
            }
          },
          "color": {"field": "Species", "type": "nominal"}
        }
      },
      {
        "mark": {"type": "circle", "tooltip": true},
        "transform": [
          {
            "joinaggregate": [
              {"field": "Body Mass (g)", "op": "values", "as": "clone"}
            ],
            "groupby": []
          },
          {"density": "Body Mass (g)", "groupby": ["clone", "Species"]},
          {
            "joinaggregate": [
              {"field": "density", "op": "max", "as": "max_density"}
            ],
            "groupby": []
          },
          {"sample": 1},
          {"flatten": ["clone"]},
          {
            "calculate": "random() * datum.max_density/raindrops + datum.max_density/raindrops/1.5",
            "as": "jitter"
          }
        ],
        "encoding": {
          "x": {"field": "clone.Body Mass (g)", "type": "quantitative"},
          "y": {"field": "jitter", "type": "quantitative"},
          "color": {"field": "Species"},
          "tooltip": [
            {"field": "clone.Species", "title": "Species", "type": "nominal"},
            {"field": "clone.Island", "title": "Island", "type": "nominal"},
            {
              "field": "clone.Body Mass (g)",
              "title": "Body Mass (g)",
              "type": "quantitative"
            }
          ]
        }
      },
      {
        "mark": {
          "type": "boxplot",
          "color": "black",
          "orient": "horizontal",
          "ticks": {"stroke": "black", "strokeWidth": 1},
          "box": {"fill": null, "stroke": "black", "strokeWidth": 2},
          "median": {"stroke": "black", "strokeWidth": 4},
          "rule": {"stroke": "black", "strokeWidth": 2},
          "outliers": false
        },
        "encoding": {
          "x": {"field": "Body Mass (g)", "type": "quantitative"},
          "y": {"datum": 0}
        }
      }
    ]
  },
  "resolve": {"scale": {"y": "independent"}},
  "config": {"facet": {"spacing": -2}}
})

# %%
import pandas as pd
import numpy as np
import altair as alt
import matplotlib as mpl

crimea_data = data.airports()
pingu_data = pd.read_json(r'./penguins.json')

alt.Chart(pingu_data).mark_point().encode(
    x='Species:N',
    y='Body Mass (g):Q',
    color='Species:N'
)
# Out:
# alt.Chart(...)

# %%
crimea_data
# Out:
#      iata                       name              city state country  \
# 0     00M                    Thigpen       Bay Springs    MS     USA
# 1     00R       Livingston Municipal        Livingston    TX     USA
# 2     00V                Meadow Lake  Colorado Springs    CO     USA
# 3     01G               Perry-Warsaw             Perry    NY     USA
# 4     01J           Hilliard Airpark          Hilliard    FL     USA
# ...   ...                        ...               ...   ...     ...
# 3371  ZEF            Elkin Municipal             Elkin    NC     USA
# 3372  ZER  Schuylkill Cty/Joe Zerbey        Pottsville    PA     USA
# 3373  ZPH      Zephyrhills Municipal       Zephyrhills    FL     USA
# 3374  ZUN                 Black Rock              Zuni    NM     USA
# 3375  ZZV       Zanesville Municipal        Zanesville    OH     USA
#
#        latitude   longitude
# 0     31.953765  -89.234505
# 1     30.685861  -95.017928
# 2     38.945749 -104.569893
# ...

# %%
VegaLite({
    "mark": "point",
    "encoding": {
        "y": {"type": "nominal", "field": " Species"},
        "x": {"type": "quantitative", "field": "Body Mass (g)"},
        "tooltip": [
            {"type": "nominal", "field": "Species"},
            {"type": "quantitative", "field": "Body Mass (g)"},
            {"type": "nominal", "field": "Island"}
        ]
    }
    
}, pingu_data)
